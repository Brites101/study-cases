# %% [markdown]
# # Setup libraries and load data

# %%
import numpy as np
import pandas as pd
import seaborn as sns; sns.set(style="ticks", color_codes=True)
import dtale
import os
import matplotlib.pyplot as plt
import ppscore as pps
import datetime
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

# %%
train_og = pd.read_csv("./train.csv")
stores = pd.read_csv("./stores.csv")
test_og = pd.read_csv("./test.csv")
features = pd.read_csv("./features.csv")
sample_submission = pd.read_csv("./sampleSubmission.csv")

# %%
#We will use store_features in train and test, so we will treat it, then merge with both afterwards
store_features = features.merge(stores, how='inner', on='Store')

# %% [markdown]
# # Treatment Phase
#
# 1. Treat Date fields

# %%
#set all date fields to datetime format
store_features.Date = pd.to_datetime(store_features.Date)
train.Date = pd.to_datetime(train.Date)
test.Date = pd.to_datetime(test.Date)

# %%
store_features['Week'] = store_features.Date.dt.week 
store_features['Year'] = store_features.Date.dt.year

# %%
store_features
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1 2010-02-05        42.31       2.572        NaN        NaN
# 1         1 2010-02-12        38.51       2.548        NaN        NaN
# 2         1 2010-02-19        39.93       2.514        NaN        NaN
# 3         1 2010-02-26        46.63       2.561        NaN        NaN
# 4         1 2010-03-05        46.50       2.625        NaN        NaN
# ...     ...        ...          ...         ...        ...        ...
# 8185     45 2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45 2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45 2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45 2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45 2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# ...

# %% [markdown]
# # Exploration Phase

# %%
weekly_sales_2010 = df[df.Year==2010]['Weekly_Sales'].groupby(df['YearWeek']).sum()
weekly_sales_2011 = df[df.Year==2011]['Weekly_Sales'].groupby(df['YearWeek']).sum()
weekly_sales_2012 = df[df.Year==2012]['Weekly_Sales'].groupby(df['YearWeek']).sum()

plt.figure(figsize=(20,8))
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values)
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values)
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values)
plt.grid()
plt.xticks(np.arange(1, 53, step=1))
plt.legend(['2010', '2011', '2012'], loc='best', fontsize=16)
plt.title('Average Weekly Sales - Per Year', fontsize=18)
plt.ylabel('Sales', fontsize=16)
plt.xlabel('YearWeek', fontsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(9, 5))
corr = df.corr()
c = plt.pcolor(corr)
plt.yticks(np.arange(0.5, len(corr.index), 1), corr.index)
plt.xticks(np.arange(0.5, len(corr.columns), 1), corr.columns,rotation=90)
fig.colorbar(c)

# %%
pps_matrix = pps.matrix(df)
sns.heatmap(pps_matrix, vmin=0, vmax=1, cmap="Blues", linewidths=2)

# %%
weekly_sales = df['Weekly_Sales'].groupby(df['Store']).mean()
plt.figure(figsize=(20,8))
sns.barplot(weekly_sales.index, weekly_sales.values)
plt.grid()
plt.title('Average Sales - per Store', fontsize=18)
plt.ylabel('Sales', fontsize=16)
plt.xlabel('Store', fontsize=16)
plt.show()

# %% [markdown]
# # Modeling Phase

# %%
X = df[stor_cols+date_cols+exte_cols+mark_cols]
y = df[target]

# %%
#split sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# # Feature Selection Phase
