# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('gci_dataset_2019.csv',encoding='latin1')

# %%
X = dataset.iloc[:,1:3].applymap(lambda x: x.replace(',', '.')).astype(float)

# %%
CL = pd.DataFrame(dataset.iloc[:,0])

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Entidades')
plt.ylabel('Distância')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(X)

# %%
plt.scatter(X[y_hc == 0].GHI, X[y_hc == 0].GOI, s = 10, c = 'red', label = 'Cluster 0')
plt.scatter(X[y_hc == 1].GHI, X[y_hc == 1].GOI, s = 10, c = 'blue', label = 'Cluster 1')
plt.scatter(X[y_hc == 2].GHI, X[y_hc == 2].GOI, s = 10, c = 'green', label = 'Cluster 2')
plt.scatter(X[y_hc == 3].GHI, X[y_hc == 3].GOI, s = 10, c = 'cyan', label = 'Cluster 3')
plt.scatter(X[y_hc == 4].GHI, X[y_hc == 4].GOI, s = 10, c = 'magenta', label = 'Cluster 4')
plt.title('Clusters')
plt.xlabel('GOI')
plt.ylabel('GHI')
plt.legend()
plt.show()

# %%
allocation = pd.concat([pd.DataFrame(CL),pd.DataFrame(y_hc)], axis=1)
allocation.sort_values(allocation.columns[1])
# Out:
#                        CL  0
# 0          BELO HORIZONTE  0
# 1                BRASÍLIA  0
# 2                CURITIBA  0
# 3                SALVADOR  0
# 5                     USP  0
# 6                 VITÓRIA  0
# 7                 ARACAJU  0
# 25         RIO DE JANEIRO  1
# 27             UBERLÂNDIA  1
# 28  VALE DO SAO FRANCISCO  1
# 29     BALNEARIO CAMBORIU  1
# 32           CAMPO GRANDE  1
# 33                CHAPECO  1
# 42               LONDRINA  1
# 35                 INSPER  1
# 38                 VIÇOSA  1
# 23              MACKENZIE  1
# 43                 MANAUS  1
# 44  SAO JOSÉ DO RIO PRETO  1
# 46               SOROCABA  1
# 34                 FRANCA  1
# 22                ITAJUBA  1
# 24                PELOTAS  1
# 20          FLORIANÓPOLIS  1
# 21         GETÚLIO VARGAS  1
# 16                 RECIFE  1
# 12                 MACEIO  1
# 48          VOLTA REDONDA  1
# 45               São Luis  2
# 41              JOINVILLE  2
# 40                GOIANIA  2
# 39                  BELÉM  2
# 47        VALE DO PARAÍBA  2
# 10            JOAO PESSOA  3
# 11                LIMEIRA  3
# 26               TERESINA  3
# 18                    ABC  3
# 13                MARINGÁ  3
# 31               BLUMENAU  3
# 30                  BAURU  3
# 19                 CUIABA  3
# 17            SANTA MARIA  3
# 36                 Palmas  3
# 37                 SANTOS  3
# 14                  NATAL  4
# 15           PORTO ALEGRE  4
# 9               FORTALEZA  4
# 8                    ESPM  4
# 4              SAO CARLOS  4
